# %% [markdown]
# <a href="https://colab.research.google.com/github/jdanielsuarez98/ElectivaDatos3/blob/main/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("")

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
data_ES = pd.read_csv("/content/drive/MyDrive/Electiva_Datos_3/CSV/MEN_ESTADISTICAS_MATRICULA_POR_MUNICIPIOS_ES.csv")
data_EM = pd.read_csv("/content/drive/MyDrive/Electiva_Datos_3/CSV/MEN_ESTADISTICAS_EN_EDUCACION_EN_PREESCOLAR__B_SICA_Y_MEDIA_POR_MUNICIPIO.csv")
data_Homicidios = pd.read_excel("/content/drive/MyDrive/Electiva_Datos_3/CSV/homicidios-ven-col.xlsx")

# %%
data_Homicidios
# Out:
#        AÑO Código delDepartamento Nombre del Departamento Código delMunicipio  \
# 0     2005                     11                      11               11001
# 1     2005                     13                      13               13001
# 2     2005                     13                      13               13074
# 3     2005                     13                      13               13188
# 4     2005                     13                      13               13248
# ...    ...                    ...                     ...                 ...
# 9624  2020                     95                      95               95001
# 9625  2020                     97                      97               97001
# 9626  2020                     99                      99               99001
# 9627  2020                     99                      99               99524
# 9628  2020                     99                      99               99624
#
# ...

# %%
data_EM
# Out:
#         AÑO  CÓDIGO_MUNICIPIO       MUNICIPIO  CÓDIGO_DEPARTAMENTO  \
# 0      2011              5001        Medellín                    5
# 1      2011              5002       Abejorral                    5
# 2      2011              5004        Abriaquí                    5
# 3      2011              5021      Alejandría                    5
# 4      2011              5030           Amagá                    5
# ...     ...               ...             ...                  ...
# 11214  2020             97889        Yavaraté                   97
# 11215  2020             99001  Puerto Carreño                   99
# 11216  2020             99524    La Primavera                   99
# 11217  2020             99624   Santa Rosalía                   99
# 11218  2020             99773        Cumaribo                   99
#
#       DEPARTAMENTO  CÓDIGO_ETC              ETC  POBLACIÓN_5_16  \
# 0        Antioquia        3759         Medellín        386466.0
# ...

# %%
data_ES
# Out:
#        AÑO Código delDepartamento Nombre del Departamento Código delMunicipio  \
# 0     2005                     11                      11               11001
# 1     2005                     13                      13               13001
# 2     2005                     13                      13               13074
# 3     2005                     13                      13               13188
# 4     2005                     13                      13               13248
# ...    ...                    ...                     ...                 ...
# 9624  2020                     95                      95               95001
# 9625  2020                     97                      97               97001
# 9626  2020                     99                      99               99001
# 9627  2020                     99                      99               99524
# 9628  2020                     99                      99               99624
#
# ...
